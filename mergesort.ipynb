# %% [markdown]
# ### Tạo 10 mảng, mỗi mảng 1 triệu số, bao gồm các số ngẫu nhiên
#
# Yêu cầu:
# - 1 mảng số thực có thứ tự tăng dần.
# - 1 mảng số thực có thứ tự giảm dần.
# - 8 mảng thứ tự ngẫu nhiên, bao gồm:
#     - 4 mảng số thực.
#     - 4 mảng số nguyên.

# %%
import numpy as np
# Seed random
np.random.seed(42)
# Kích thước mảng
n = 1_000_000

# 1. Mảng số thực sắp xếp theo thứ tự tăng dần
arr_asc_float = np.sort(np.random.rand(n))

# 2. Mảng số thực sắp xếp theo thứ tự giảm dần
arr_desc_float = np.sort(np.random.rand(n))[::-1]

# 3. 8 mảng ngẫu nhiên
# 4 mảng số thực ngẫu nhiên
arr_rand_floats = [np.random.rand(n) for _ in range(4)]

# 4 mảng số nguyên ngẫu nhiên (giả sử trong khoảng 0 đến 1.000.000)
arr_rand_ints = [np.random.randint(0, n, n) for _ in range(4)]

# %%
# Cài đặt Merge Sort
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        L = arr[:mid]
        R = arr[mid:]

        merge_sort(L)
        merge_sort(R)

        i = j = k = 0

        while i < len(L) and j < len(R):
            if L[i] < R[j]:
                arr[k] = L[i]
                i += 1
            else:
                arr[k] = R[j]
                j += 1
            k += 1

        while i < len(L):
            arr[k] = L[i]
            i += 1
            k += 1

        while j < len(R):
            arr[k] = R[j]
            j += 1
            k += 1
    return arr

# %%
# Đo thời gian chạy merge_sort trên mảng số thực tăng dần
# %time sorted_arr = merge_sort(arr_asc_float)
# Out:
# CPU times: total: 3.34 s
# Wall time: 3.43 s

# %%
# Đo thời gian chạy merge_sort trên mảng số thực giảm dần
# %time sorted_arr = merge_sort(arr_desc_float)
# Out:
# CPU times: total: 3.34 s
# Wall time: 3.35 s

# %%
# Đo thời gian chạy merge_sort trên 4 mảng số thực ngẫu nhiên
for i, arr in enumerate(arr_rand_floats):
    # %time sorted_arr = merge_sort(arr)
# Out:
# CPU times: total: 3.77 s
# Wall time: 3.78 s
# CPU times: total: 3.83 s
# Wall time: 3.9 s
# CPU times: total: 3.72 s
# Wall time: 3.73 s
# CPU times: total: 3.75 s
# Wall time: 3.74 s

# %%
# Đo thời gian chạy merge_sort trên 4 mảng số nguyên ngẫu nhiên
for i, arr in enumerate(arr_rand_ints):
    # %time sorted_arr = merge_sort(arr)
# Out:
# CPU times: total: 4 s
# Wall time: 4.02 s
# CPU times: total: 3.95 s
# Wall time: 3.96 s
# CPU times: total: 3.98 s
# Wall time: 3.99 s
# CPU times: total: 3.95 s
# Wall time: 3.99 s
