# %% [markdown]
# ### Tạo 10 mảng, mỗi mảng 1 triệu số, bao gồm các số ngẫu nhiên
#
# Yêu cầu:
# - 1 mảng số thực có thứ tự tăng dần.
# - 1 mảng số thực có thứ tự giảm dần.
# - 8 mảng thứ tự ngẫu nhiên, bao gồm:
#     - 4 mảng số thực.
#     - 4 mảng số nguyên.

# %%
import numpy as np
# Seed random
np.random.seed(42)
# Kích thước mảng
n = 1_000_000

# 1. Mảng số thực sắp xếp theo thứ tự tăng dần
arr_asc_float = np.sort(np.random.rand(n))

# 2. Mảng số thực sắp xếp theo thứ tự giảm dần
arr_desc_float = np.sort(np.random.rand(n))[::-1]

# 3. 8 mảng ngẫu nhiên
# 4 mảng số thực ngẫu nhiên
arr_rand_floats = [np.random.rand(n) for _ in range(4)]

# 4 mảng số nguyên ngẫu nhiên (giả sử trong khoảng 0 đến 1.000.000)
arr_rand_ints = [np.random.randint(0, n, n) for _ in range(4)]

# %%
# Đo thời gian chạy sort của numPy trên mảng số thực tăng dần
# %time sorted_arr = np.sort(arr_asc_float)
# Out:
# CPU times: total: 31.2 ms
# Wall time: 42.4 ms

# %%
# Đo thời gian chạy sort của numPy trên mảng số thực giảm dần
# %time sorted_arr = np.sort(arr_desc_float)
# Out:
# CPU times: total: 46.9 ms
# Wall time: 41 ms

# %%
# Đo thời gian chạy sort của numPy trên 4 mảng số thực ngẫu nhiên
for i, arr in enumerate(arr_rand_floats):
    # %time sorted_arr = np.sort(arr)
# Out:
# CPU times: total: 46.9 ms
# Wall time: 43.7 ms
# CPU times: total: 46.9 ms
# Wall time: 44.4 ms
# CPU times: total: 31.2 ms
# Wall time: 43.7 ms
# CPU times: total: 46.9 ms
# Wall time: 42.9 ms

# %%
# Đo thời gian chạy sort cua numPy trên 4 mảng số nguyên ngẫu nhiên
for i, arr in enumerate(arr_rand_ints):
    # %time sorted_arr = np.sort(arr)
# Out:
# CPU times: total: 15.6 ms
# Wall time: 23.7 ms
# CPU times: total: 31.2 ms
# Wall time: 22.6 ms
# CPU times: total: 15.6 ms
# Wall time: 23.1 ms
# CPU times: total: 31.2 ms
# Wall time: 22.1 ms
